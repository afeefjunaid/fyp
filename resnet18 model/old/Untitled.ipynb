# %%
import os
import copy
import time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data import random_split, DataLoader
from sklearn.metrics import classification_report

# %%
# Configs
data_dir = '../Preprocessing/New Dataset'
batch_size = 32

start_epeoch=100
end_epoch=501
step=5
learning_rate = 0.001
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_save_path = 'best_model.pth'
num_classes = 3  # dry, normal, oily

# %%
# Transforms
mean = [0.485, 0.456, 0.406]  # ImageNet mean
std = [0.229, 0.224, 0.225]   # ImageNet std

# %%
# With augmentation
data_transforms_aug = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(brightness=0.2, contrast=0.2),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
}

# %%
# Without augmentation
data_transforms_plain = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
}

# %%
def load_datasets(transforms_dict):
    full_dataset = datasets.ImageFolder(data_dir, transform=transforms_dict['train'])
    val_dataset = datasets.ImageFolder(data_dir, transform=transforms_dict['val'])

    train_size = int(0.8 * len(full_dataset))
    val_size = len(full_dataset) - train_size

    train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader

# %%
def train_model(model, dataloaders, criterion, optimizer, scheduler, end_epoch, mode_name):
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(start_epeoch,end_epoch,step):
        print(f'\n[{mode_name}] Epoch {epoch + 1}/{end_epoch}')
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    _, preds = torch.max(outputs, 1)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)

            print(f'{phase.capitalize()} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # Save best model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                torch.save(model.state_dict(), model_save_path)
                print("✅ Saved Best Model")

        scheduler.step()
        
    print(f'\nBest Validation Acc: {best_acc:.4f}')
    model.load_state_dict(best_model_wts)
    return model

# %%
def test_model(model, dataloader):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=['dry', 'normal', 'oily']))

# %%
# Function to run entire training
def run_pipeline(use_aug=True):
    print("\n" + "=" * 60)
    print("Using Augmentation" if use_aug else "Without Augmentation")
    print("=" * 60)

    transforms_dict = data_transforms_aug if use_aug else data_transforms_plain
    train_loader, val_loader = load_datasets(transforms_dict)
    dataloaders = {'train': train_loader, 'val': val_loader}

    # Load pretrained ResNet18
    model_ft = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)
    num_ftrs = model_ft.fc.in_features
    model_ft.fc = nn.Linear(num_ftrs, num_classes)
    model_ft = model_ft.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model_ft.parameters(), lr=learning_rate)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

    model_ft = train_model(model_ft, dataloaders, criterion, optimizer, scheduler, end_epoch,
                           mode_name="Aug" if use_aug else "Plain")

    # Test model
    print("\nTesting on Test Set")
    _, test_loader = load_datasets(transforms_dict)
    test_model(model_ft, test_loader)

# %%
run_pipeline(use_aug=False)
# Out:
# ============================================================
# Without Augmentation
# ============================================================
#
# [Plain] Epoch 101/501
# Train Loss: 0.7479 Acc: 0.7012
# Val Loss: 0.6958 Acc: 0.7048
# ✅ Saved Best Model
#
# [Plain] Epoch 106/501
# Train Loss: 0.5452 Acc: 0.7696
# Val Loss: 0.6391 Acc: 0.7238
# ✅ Saved Best Model
#
# [Plain] Epoch 111/501
# Train Loss: 0.4918 Acc: 0.8024
# Val Loss: 0.6468 Acc: 0.7048
#
# [Plain] Epoch 116/501
# Train Loss: 0.4555 Acc: 0.8089
# Val Loss: 0.5693 Acc: 0.7786
# ✅ Saved Best Model
#
# [Plain] Epoch 121/501
# Train Loss: 0.4276 Acc: 0.8351
# Val Loss: 0.7196 Acc: 0.7476
#
# [Plain] Epoch 126/501
# Train Loss: 0.3472 Acc: 0.8607
# Val Loss: 0.5073 Acc: 0.8048
# ✅ Saved Best Model
#
# [Plain] Epoch 131/501
# Train Loss: 0.2628 Acc: 0.9024
# Val Loss: 0.5291 Acc: 0.7857
#
# [Plain] Epoch 136/501
# Train Loss: 0.2120 Acc: 0.9202
# Val Loss: 0.4994 Acc: 0.8095
# ✅ Saved Best Model
#
# [Plain] Epoch 141/501
# Train Loss: 0.1714 Acc: 0.9375
# Val Loss: 0.5239 Acc: 0.8024
#
# [Plain] Epoch 146/501
# Train Loss: 0.1494 Acc: 0.9470
# Val Loss: 0.4988 Acc: 0.8167
# ✅ Saved Best Model
#
# [Plain] Epoch 151/501
# Train Loss: 0.1087 Acc: 0.9649
# Val Loss: 0.4789 Acc: 0.8143
#
# [Plain] Epoch 156/501
# Train Loss: 0.1062 Acc: 0.9667
# Val Loss: 0.4831 Acc: 0.8143
#
# [Plain] Epoch 161/501
# Train Loss: 0.0922 Acc: 0.9720
# Val Loss: 0.5008 Acc: 0.8000
#
# [Plain] Epoch 166/501
# Train Loss: 0.0842 Acc: 0.9714
# Val Loss: 0.5061 Acc: 0.8071
#
# [Plain] Epoch 171/501
# Train Loss: 0.0909 Acc: 0.9690
# Val Loss: 0.4934 Acc: 0.8214
# ✅ Saved Best Model
#
# [Plain] Epoch 176/501
# Train Loss: 0.0837 Acc: 0.9732
# Val Loss: 0.4955 Acc: 0.8214
#
# [Plain] Epoch 181/501
# Train Loss: 0.0841 Acc: 0.9756
# Val Loss: 0.4970 Acc: 0.8214
#
# [Plain] Epoch 186/501
# Train Loss: 0.0857 Acc: 0.9708
# Val Loss: 0.5013 Acc: 0.8167
#
# [Plain] Epoch 191/501
# Train Loss: 0.0800 Acc: 0.9726
# Val Loss: 0.4989 Acc: 0.8190
#
# [Plain] Epoch 196/501
# Train Loss: 0.0890 Acc: 0.9702
# Val Loss: 0.5081 Acc: 0.8167
#
# [Plain] Epoch 201/501
# Train Loss: 0.0773 Acc: 0.9756
# Val Loss: 0.4930 Acc: 0.8262
# ✅ Saved Best Model
#
# [Plain] Epoch 206/501
# Train Loss: 0.0754 Acc: 0.9786
# Val Loss: 0.5052 Acc: 0.8190
#
# [Plain] Epoch 211/501
# Train Loss: 0.0789 Acc: 0.9744
# Val Loss: 0.5020 Acc: 0.8190
#
# [Plain] Epoch 216/501
# Train Loss: 0.0788 Acc: 0.9762
# Val Loss: 0.4980 Acc: 0.8238
#
# [Plain] Epoch 221/501
# Train Loss: 0.0834 Acc: 0.9726
# Val Loss: 0.4955 Acc: 0.8167
#
# [Plain] Epoch 226/501
# Train Loss: 0.0788 Acc: 0.9780
# Val Loss: 0.4936 Acc: 0.8262
#
# [Plain] Epoch 231/501
# Train Loss: 0.0809 Acc: 0.9720
# Val Loss: 0.4963 Acc: 0.8214
#
# [Plain] Epoch 236/501
# Train Loss: 0.0833 Acc: 0.9744
# Val Loss: 0.4970 Acc: 0.8190
#
# [Plain] Epoch 241/501
# Train Loss: 0.0827 Acc: 0.9750
# Val Loss: 0.4943 Acc: 0.8286
# ✅ Saved Best Model
#
# [Plain] Epoch 246/501
# Train Loss: 0.0779 Acc: 0.9750
# Val Loss: 0.5035 Acc: 0.8167
#
# [Plain] Epoch 251/501
# Train Loss: 0.0803 Acc: 0.9720
# Val Loss: 0.5000 Acc: 0.8238
#
# [Plain] Epoch 256/501
# Train Loss: 0.0768 Acc: 0.9732
# Val Loss: 0.5030 Acc: 0.8143
#
# [Plain] Epoch 261/501
# Train Loss: 0.0761 Acc: 0.9762
# Val Loss: 0.5016 Acc: 0.8190
#
# [Plain] Epoch 266/501
# Train Loss: 0.0835 Acc: 0.9720
# Val Loss: 0.5051 Acc: 0.8238
#
# [Plain] Epoch 271/501
# Train Loss: 0.0874 Acc: 0.9720
# Val Loss: 0.5126 Acc: 0.8143
#
# [Plain] Epoch 276/501
# Train Loss: 0.0782 Acc: 0.9768
# Val Loss: 0.5083 Acc: 0.8167
#
# [Plain] Epoch 281/501
# Train Loss: 0.0802 Acc: 0.9696
# Val Loss: 0.5127 Acc: 0.8095
#
# [Plain] Epoch 286/501
# Train Loss: 0.0782 Acc: 0.9756
# Val Loss: 0.5073 Acc: 0.8143
#
# [Plain] Epoch 291/501
# Train Loss: 0.0821 Acc: 0.9744
# Val Loss: 0.4991 Acc: 0.8167
#
# [Plain] Epoch 296/501
# Train Loss: 0.0808 Acc: 0.9732
# Val Loss: 0.5069 Acc: 0.8143
#
# [Plain] Epoch 301/501
# Train Loss: 0.0803 Acc: 0.9774
# Val Loss: 0.4999 Acc: 0.8190
#
# [Plain] Epoch 306/501
# Train Loss: 0.1047 Acc: 0.9690
# Val Loss: 0.5114 Acc: 0.8167
#
# [Plain] Epoch 311/501
# Train Loss: 0.0797 Acc: 0.9762
# Val Loss: 0.4936 Acc: 0.8238
#
# [Plain] Epoch 316/501
# Train Loss: 0.0802 Acc: 0.9738
# Val Loss: 0.4996 Acc: 0.8190
#
# [Plain] Epoch 321/501
# Train Loss: 0.0842 Acc: 0.9750
# Val Loss: 0.4996 Acc: 0.8238
#
# [Plain] Epoch 326/501
# Train Loss: 0.0774 Acc: 0.9744
# Val Loss: 0.4987 Acc: 0.8238
#
# [Plain] Epoch 331/501
# Train Loss: 0.0842 Acc: 0.9720
# Val Loss: 0.5018 Acc: 0.8167
#
# [Plain] Epoch 336/501
# Train Loss: 0.0828 Acc: 0.9726
# Val Loss: 0.5005 Acc: 0.8143
#
# [Plain] Epoch 341/501
# Train Loss: 0.0826 Acc: 0.9702
# Val Loss: 0.5085 Acc: 0.8167
#
# [Plain] Epoch 346/501
# Train Loss: 0.0805 Acc: 0.9780
# Val Loss: 0.4970 Acc: 0.8238
#
# [Plain] Epoch 351/501
# Train Loss: 0.0823 Acc: 0.9738
# Val Loss: 0.5044 Acc: 0.8119
#
# [Plain] Epoch 356/501
# Train Loss: 0.0820 Acc: 0.9708
# Val Loss: 0.4990 Acc: 0.8167
#
# [Plain] Epoch 361/501
# Train Loss: 0.0803 Acc: 0.9714
# Val Loss: 0.5125 Acc: 0.8238
#
# [Plain] Epoch 366/501
# Train Loss: 0.0749 Acc: 0.9774
# Val Loss: 0.5048 Acc: 0.8095
#
# [Plain] Epoch 371/501
# Train Loss: 0.0889 Acc: 0.9702
# Val Loss: 0.4975 Acc: 0.8286
#
# [Plain] Epoch 376/501
# Train Loss: 0.0821 Acc: 0.9774
# Val Loss: 0.5051 Acc: 0.8167
#
# [Plain] Epoch 381/501
# Train Loss: 0.0792 Acc: 0.9732
# Val Loss: 0.4966 Acc: 0.8238
#
# [Plain] Epoch 386/501
# Train Loss: 0.0778 Acc: 0.9732
# Val Loss: 0.5055 Acc: 0.8119
#
# [Plain] Epoch 391/501
# Train Loss: 0.0880 Acc: 0.9732
# Val Loss: 0.4952 Acc: 0.8238
#
# [Plain] Epoch 396/501
# Train Loss: 0.0782 Acc: 0.9750
# Val Loss: 0.4953 Acc: 0.8214
#
# [Plain] Epoch 401/501
# Train Loss: 0.0767 Acc: 0.9744
# Val Loss: 0.5025 Acc: 0.8190
#
# [Plain] Epoch 406/501
# Train Loss: 0.0804 Acc: 0.9744
# Val Loss: 0.4991 Acc: 0.8167
#
# [Plain] Epoch 411/501
# Train Loss: 0.0790 Acc: 0.9750
# Val Loss: 0.5126 Acc: 0.8143
#
# [Plain] Epoch 416/501
# Train Loss: 0.0813 Acc: 0.9750
# Val Loss: 0.4972 Acc: 0.8214
#
# [Plain] Epoch 421/501
# Train Loss: 0.0789 Acc: 0.9762
# Val Loss: 0.4899 Acc: 0.8143
#
# [Plain] Epoch 426/501
# Train Loss: 0.0868 Acc: 0.9714
# Val Loss: 0.4991 Acc: 0.8214
#
# [Plain] Epoch 431/501
# Train Loss: 0.0751 Acc: 0.9798
# Val Loss: 0.5055 Acc: 0.8190
#
# [Plain] Epoch 436/501
# Train Loss: 0.0762 Acc: 0.9756
# Val Loss: 0.5031 Acc: 0.8214
#
# [Plain] Epoch 441/501
# Train Loss: 0.0837 Acc: 0.9720
# Val Loss: 0.5052 Acc: 0.8167
#
# [Plain] Epoch 446/501
# Train Loss: 0.0852 Acc: 0.9726
# Val Loss: 0.4965 Acc: 0.8214
#
# [Plain] Epoch 451/501
# Train Loss: 0.0820 Acc: 0.9762
# Val Loss: 0.4995 Acc: 0.8214
#
# [Plain] Epoch 456/501
# Train Loss: 0.0793 Acc: 0.9780
# Val Loss: 0.5021 Acc: 0.8119
#
# [Plain] Epoch 461/501
# Train Loss: 0.0798 Acc: 0.9738
# Val Loss: 0.4995 Acc: 0.8190
#
# [Plain] Epoch 466/501
# Train Loss: 0.0862 Acc: 0.9720
# Val Loss: 0.5023 Acc: 0.8143
#
# [Plain] Epoch 471/501
# Train Loss: 0.0836 Acc: 0.9744
# Val Loss: 0.5076 Acc: 0.8190
#
# [Plain] Epoch 476/501
# Train Loss: 0.0786 Acc: 0.9756
# Val Loss: 0.4973 Acc: 0.8190
#
# [Plain] Epoch 481/501
# Train Loss: 0.0812 Acc: 0.9744
# Val Loss: 0.5034 Acc: 0.8214
#
# [Plain] Epoch 486/501
# Train Loss: 0.0829 Acc: 0.9732
# Val Loss: 0.5007 Acc: 0.8167
#
# [Plain] Epoch 491/501
# Train Loss: 0.0829 Acc: 0.9708
# Val Loss: 0.5047 Acc: 0.8214
#
# [Plain] Epoch 496/501
# Train Loss: 0.0820 Acc: 0.9756
# Val Loss: 0.5062 Acc: 0.8143
#
# [Plain] Epoch 501/501
# Train Loss: 0.0777 Acc: 0.9726
# Val Loss: 0.5058 Acc: 0.8167
#
# Best Validation Acc: 0.8286
#
# Testing on Test Set
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          dry       0.96      0.95      0.95       140
#       normal       0.98      0.97      0.98       132
#         oily       0.95      0.97      0.96       148
#
#     accuracy                           0.96       420
#    macro avg       0.97      0.96      0.96       420
# weighted avg       0.96      0.96      0.96       420
